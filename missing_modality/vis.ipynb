# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()

####### Missing Modality ########
x = np.array(["10%", "20%", "30%", "40%", "50%"])

# y_chat = np.array([78.42, 78.18, 79.31, 82.56, 77.19, 78.67])
# plt.plot(x, y_chat, label='SE-MSCNN', marker = 'o', alpha=0.75)

y_nch = np.array([77.67, 72.55, 67.66, 63.46, 60.66])
plt.plot(x, y_nch, label='CNN+LSTM', marker = 'o', alpha=0.75)

y_nch = np.array([80.46, 73.54, 67.78, 63.57, 60.87])
plt.plot(x, y_nch, label='CNN', marker = 'o', alpha=0.75)

y_nch = np.array([87.04, 84.23, 80.66, 77.57, 74.55])
plt.plot(x, y_nch, label='Transformer', marker = 'o', alpha=0.75)

y_nch = np.array([90.42, 87.64, 84.55, 81.19, 77.15])
plt.plot(x, y_nch, label='Ours', marker = 'o', alpha=0.75)

plt.ylim([50,100])
plt.xlabel('Missingness Ratio')
plt.ylabel('AUROC')
plt.legend(loc='lower right')
fig.set_size_inches(6, 4)
plt.savefig('.\\img\\missing.svg', format="svg")

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
data = np.load("/media/hamed/CHAT Dataset/chat_b_30x64_0.npz", allow_pickle=True)

# %%
data['x'].shape
# Out:
# (10230, 1920, 9)

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()

####### Noisy Modality ########
x = np.array(['10', "20", "30", "40", "50"])

# y_chat = np.array([78.42, 78.18, 79.31, 82.56, 77.19, 78.67])
# plt.plot(x, y_chat, label='SE-MSCNN', marker = 'o', alpha=0.75)

y_nch = np.array([64.40, 67.97, 78.89, 84.77, 84.70])
plt.plot(x, y_nch, label='CNN+LSTM', marker = 'o', alpha=0.75)

y_nch = np.array([83.06, 84.92, 89.14, 89.81, 90.04])
plt.plot(x, y_nch, label='CNN', marker = 'o', alpha=0.75)

y_nch = np.array([84.65, 85.48,  87.65, 89.71, 90.26])
plt.plot(x, y_nch, label='Transformer', marker = 'o', alpha=0.75)

y_nch = np.array([89.60, 92.34, 92.94, 92.97, 92.96])
plt.plot(x, y_nch, label='Ours', marker = 'o', alpha=0.75)

plt.ylim([50,100])
plt.xlabel('Signal to Noise Ratio (dB)')
plt.ylabel('AUROC')
plt.legend(loc='lower right')
fig.set_size_inches(6, 4)
plt.savefig('.\\img\\noisy.svg', format="svg")
