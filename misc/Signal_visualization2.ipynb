# %%
import mne
import numpy as np
import matplotlib.pyplot as plt
from mne import make_fixed_length_events
import sleep_study as ss
import scipy

# %%
data = np.load("C:\\Data\\raw_all.npz", allow_pickle=True)
x, y_apnea, y_hypopnea = data['x'], data['y_apnea'], data['y_hypopnea']

# %%
x = x[0]
print(x.shape)
# Out:
# (12683, 180, 18)

# %%
# 0    EOG LOC-M2
plt.plot(x[2678,:,17])

# %%
plt.plot(scipy.signal.resample(data[100,0,:1024], 90))

# %%
# 1 EOG ROC-M1
plt.plot(data[100,1,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,1,:1024], 90))

# %%
# 2 EEG CHIN1-CHIN2
plt.plot(data[100,2,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,2,:1024], 90))

# %%
# 3 EEG F3-M2
plt.plot(data[100,3,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,3,:1024], 90))

# %%
# 4 EEG F4-M1
plt.plot(data[100,4,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,4,:1024], 90))

# %%
 # 5  EEG C3-M2
plt.plot(data[100,5,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,5,:1024], 90))

# %%
# 6 EEG C4-M1
plt.plot(data[100,6,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,6,:1024], 90))

# %%
# 7 EEG O1-M2
plt.plot(data[100,7,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,7,:1024], 90))

# %%
# 8 EEG O2-M1
plt.plot(data[100,8,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,8,:1024], 90))

# %%
# 9 EEG CZ-O1
plt.plot(data[100,9,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,9,:1024], 90))

# %%
# 10 EMG LLEG-RLEG
plt.plot(data[100,10,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,10,:1024], 90))

# %%
# 11 ECG EKG2-EKG
plt.plot(data[100,11,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,11,:1024], 90))

# %%
# 12 SNORE
plt.plot(data[100,12,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,12,:1024], 90))

# %%
# 13 RESP PTAF
plt.plot(data[100,13,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,13,:1024], 90))

# %%
# 14 RESP AIRFLOW
plt.plot(data[100,14,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,14,:1024], 90))

# %%
# 15 RESP THORACIC
plt.plot(data[100,15,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,15,:1024], 90))

# %%
# 16 RESP ABDOMINAL
plt.plot(data[100,16,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,16,:1024], 90))

# %%
# 17 SPO2
plt.plot(data[100,17,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,17,:1024], 90))

# %%
# 18 RATE
plt.plot(data[100,18,:1024])

# %%
plt.plot(scipy.signal.resample(data[100,18,:1024], 90))

# %%
# 19 ETCO2
plt.plot(data[500,19,:1024])

# %%
# 20 CAPNO
plt.plot(data[500,20,:1024])

# %%
plt.plot(scipy.signal.resample(data[500,20,:1024], 90))

# %%
# 21 RESP RATE
plt.plot(data[500,21,:1024])

# %%
plt.plot(scipy.signal.resample(data[500,21,:1024], 90))

# %%
# 22 C-FLOW
plt.plot(data[500,22,:1024])

# %%
plt.plot(scipy.signal.resample(data[500,22,:1024], 90))

# %%
# 23 TIDAL VOL
plt.plot(data[332,23,:1024])

# %%
plt.plot(scipy.signal.resample(data[332,23,:1024], 90))

# %%
# 24 PRESSURE
plt.plot(data[32,24,:1024])
